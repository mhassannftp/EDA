# %% [markdown]
# # The Spark Foundation Network
#
# # Author: Muhammad Hassan
# ## GRIPOCTUBER21
#
# # Task#4 Exploratory Data Analysis -EDA Perform EDA on dataset "Global Terrorism

# %% [markdown]
# ## Language: Python

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/user/globalterrorismdb.csv',encoding='latin=1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region    state  \
# 0  Dominican Republic       2  Central America & Caribbean      NaN
# 1              Mexico       1                North America  Federal
# 2         Philippines       5               Southeast Asia   Tarlac
# 3              Greece       8               Western Europe   Attica
# 4               Japan       4                    East Asia  Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
pd.set_option('Display.max_columns',None)
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region    state  \
# 0  Dominican Republic       2  Central America & Caribbean      NaN
# 1              Mexico       1                North America  Federal
# 2         Philippines       5               Southeast Asia   Tarlac
# 3              Greece       8               Western Europe   Attica
# 4               Japan       4                    East Asia  Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
plt.figure(figsize=(20,8))
plt.xlabel("Regions")
plt.xticks(rotation= 90)
sns.countplot(x='Region', data=df);

# %% [markdown]
# ## Destructive Features or Most Occurning

# %%
print("Country with the most attact = ",df['Country'].value_counts().idxmax())
print("Region with the most attact = ",df['Region'].value_counts().idxmax())
print("City with the most attact = ",df['city'].value_counts().index[1])
print("Year with the most attact = ",df['Year'].value_counts().idxmax())
print("Month with the most attact = ",df['Month'].value_counts().idxmax())
print("Group with the most attact = ",df['Group'].value_counts().index[1])
print("Mostattact Type = ",df['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attact =  Iraq
# Region with the most attact =  Middle East & North Africa
# City with the most attact =  Baghdad
# Year with the most attact =  2014
# Month with the most attact =  5
# Group with the most attact =  Taliban
# Mostattact Type =  Bombing/Explosion

# %% [markdown]
# ## Terrorist Activities by Region in each Year.

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area', figsize=(15,10))
plt.title("Terrorist Activities by Region in each Year")
plt.ylabel("Number of Attacts")
plt.show()

# %% [markdown]
# ## Scicide Attack by Region in each Year

# %%
pd.crosstab(df.Region, df.suicide).plot(kind='bar', figsize=(12,8))
plt.title("Suicide Attact by Region in each Year")
plt.ylabel("Number of Attacts")
plt.show();

# %% [markdown]
# ## Top 20 Countries affected by Terror Attacks

# %%
df.Country.value_counts()[:20]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
plt.subplots(figsize=(18,8))
sns.color_palette("viridis")
sns.barplot(df['Country'].value_counts()[:20].index,df['Country'].value_counts()[:20].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# Iraq is the most affacted Country and second most affected country is Pakistan

# %% [markdown]
# ## Most Attach Types

# %%
plt.subplots(figsize=(15,8))
sns.color_palette("Paired")
sns.barplot(df['AttackType'].value_counts()[:20].index,df['AttackType'].value_counts()[:20].values)
plt.title('Most Attacks Type')
plt.xlabel('Attack Type')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# Most Attach Types are Bombling/Explossion and than Armed Assanut

# %%
df.Group.value_counts()[:20]
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# National Liberation Army of Colombia (ELN)           1561
# ...

# %%
plt.subplots(figsize=(18,8))
sns.color_palette("Set2")
sns.barplot(df['Group'].value_counts()[:20].index,df['Group'].value_counts()[:20])
plt.title('Most wannted Groups of Terror')
plt.xlabel('Groups')
plt.ylabel('Counts')
plt.xticks(rotation= 270)
plt.show()

# %% [markdown]
# The most wanted or dangous group are "Unkown" and than Taliban
